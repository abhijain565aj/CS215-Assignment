# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train_data = pd.read_csv('data/5/train.csv')

# %%
train_data.head()
# Out:
#    id   Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0   0  639.0       25.0      0.50     0.25     0.75   0.63              94.6
# 1   1  124.0       12.5      0.25     0.25     0.25   0.25              77.4
# 2   2  485.0       25.0      0.50     0.25     0.38   0.75              94.6
# 3   3  324.0       12.5      0.25     0.25     0.75   0.75              94.6
# 4   4  235.0       12.5      0.25     0.25     0.50   0.63              77.4
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              57.2                  79.0              68.2              33.0
# 1              46.8                  64.7              55.8              27.0
# 2              57.2                  79.0              68.2              33.0
# 3              57.2                  79.0              68.2              33.0
# 4              46.8                  64.7              55.8              27.0
#
#    AverageOfLowerTRange  RainingDays  AverageRainingDays  fruitset  fruitmass  \
# 0                  55.9         34.0                0.56  0.402948   0.409261
# 1                  45.8         34.0                0.56  0.500438   0.445494
# 2                  55.9         24.0                0.39  0.509001   0.459421
# 3                  55.9         16.0                0.26  0.583379   0.498056
# 4                  45.8         24.0                0.39  0.447669   0.423764
#
#        seeds       yield
# 0  31.274591  4418.44126
# 1  34.467567  5862.80545
# 2  36.624966  6079.08526
# 3  40.865478  7400.77538
# 4  33.298861  4858.24073

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15000 non-null  int64
#  1   Row#                  15000 non-null  float64
#  2   clonesize             15000 non-null  float64
#  3   honeybee              15000 non-null  float64
#  4   bumbles               15000 non-null  float64
#  5   andrena               15000 non-null  float64
#  6   osmia                 15000 non-null  float64
#  7   MaxOfUpperTRange      15000 non-null  float64
#  8   MinOfUpperTRange      15000 non-null  float64
#  9   AverageOfUpperTRange  15000 non-null  float64
#  10  MaxOfLowerTRange      15000 non-null  float64
#  11  MinOfLowerTRange      15000 non-null  float64
#  12  AverageOfLowerTRange  15000 non-null  float64
#  13  RainingDays           15000 non-null  float64
#  14  AverageRainingDays    15000 non-null  float64
#  15  fruitset              15000 non-null  float64
#  16  fruitmass             15000 non-null  float64
#  17  seeds                 15000 non-null  float64
#  18  yield                 15000 non-null  float64
# dtypes: float64(18), int64(1)
# memory usage: 2.2 MB

# %%
train_data.describe().T
# Out:
#                         count         mean          std          min  \
# id                    15000.0  7499.500000  4330.271354     0.000000
# Row#                  15000.0   429.028333   213.858896     0.000000
# clonesize             15000.0    19.720333     6.644401    10.000000
# honeybee              15000.0     0.383967     0.260647     0.000000
# bumbles               15000.0     0.285445     0.059179     0.000000
# andrena               15000.0     0.487979     0.147186     0.000000
# osmia                 15000.0     0.589398     0.144559     0.000000
# MaxOfUpperTRange      15000.0    82.223840     9.080973    69.700000
# MinOfUpperTRange      15000.0    49.703600     5.506574    39.000000
# AverageOfUpperTRange  15000.0    68.700520     7.586826    58.200000
# MaxOfLowerTRange      15000.0    59.267747     6.562923    50.200000
# MinOfLowerTRange      15000.0    28.678920     3.172043    24.300000
# AverageOfLowerTRange  15000.0    48.600493     5.354241    41.200000
# RainingDays           15000.0    18.689772    11.826593     1.000000
# AverageRainingDays    15000.0     0.325415     0.166033     0.060000
# fruitset              15000.0     0.501637     0.076552     0.192732
# fruitmass             15000.0     0.446335     0.038003     0.246568
# seeds                 15000.0    36.134737     4.094260    22.079199
# yield                 15000.0  6033.586197  1349.801334  1637.704020
#
#                               25%          50%           75%           max
# id                    3749.750000  7499.500000  11249.250000  14999.000000
# Row#                   248.000000   466.000000    599.000000    776.000000
# clonesize               12.500000    25.000000     25.000000     40.000000
# honeybee                 0.250000     0.500000      0.500000     18.430000
# bumbles                  0.250000     0.250000      0.380000      0.585000
# andrena                  0.380000     0.500000      0.630000      0.750000
# osmia                    0.500000     0.630000      0.750000      0.750000
# MaxOfUpperTRange        77.400000    86.000000     86.000000     94.600000
# MinOfUpperTRange        46.800000    52.000000     52.000000     57.200000
# AverageOfUpperTRange    64.700000    71.900000     71.900000     79.000000
# MaxOfLowerTRange        55.800000    62.000000     62.000000     68.200000
# MinOfLowerTRange        27.000000    30.000000     30.000000     33.000000
# AverageOfLowerTRange    45.800000    50.800000     50.800000     68.200000
# RainingDays             16.000000    16.000000     24.000000     34.000000
# AverageRainingDays       0.260000     0.260000      0.390000      0.560000
# fruitset                 0.453462     0.506346      0.564795      0.917343
# fruitmass                0.418732     0.446570      0.472670      0.757564
# seeds                   33.267137    36.040675     39.158238     46.718182
# yield                 5128.163510  6132.417380   7044.567610   8969.401840

# %%
data = train_data.drop(['id'], axis=1) # Drop unnecessary columns (e.g., id) for correlation analysis
corr_matrix = data.corr()
plt.figure(figsize=(9, 9))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0,annot_kws={"size": 8}, linewidths=1, linecolor='black')
plt.title('Correlation Matrix Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Heatmap')

# %% [markdown]
# The correlation matrix suggests that the yield is more correlated with fruitset, fruitmass, seeds, raining days, clonesize.

# %%
features = ['Row#', 'clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia', 'MaxOfUpperTRange', 'MinOfUpperTRange', 'AverageOfUpperTRange', 'MaxOfLowerTRange', 'MinOfLowerTRange', 'AverageOfLowerTRange', 'RainingDays', 'AverageRainingDays', 'fruitset', 'fruitmass', 'seeds']

f_taken = ['clonesize', 'AverageRainingDays', 'fruitset', 'fruitmass', 'seeds'] #features for polynomial features

def X_creator(train_data):
    return np.c_[train_data[features].values, train_data[f_taken].values**2, train_data[f_taken].values**3]

X_train = X_creator(train_data=train_data)

# Y_train as the vector of the yield column 
Y_train = train_data.iloc[:, -1].values

# %% [markdown]
# $$\hat{\beta} = (X^TX)^{-1}X^Ty$$

# %%
def OLS(X, y):
    # Add intercept term (column of ones)
    X = np.c_[np.ones(X.shape[0]), X]
    # Calculate OLS estimates using normal equation
    beta = np.linalg.inv(X.T @ X) @ X.T @ y
    return beta

# %%
test_data = pd.read_csv('data/5/test.csv')
id_test = test_data.iloc[:, 0].values
# X_test = test_data.iloc[:, 1:].values

X_test = X_creator(test_data)

def test(X_test = X_test):
    beta = OLS(X_train, Y_train)
    print(beta)
    # Add intercept term to X_test to match X_train
    X_test_with_intercept = np.c_[np.ones(X_test.shape[0]), X_test]
    Y_pred = X_test_with_intercept @ beta
    return Y_pred

Y_pred = test()
submission = pd.DataFrame({'id': id_test, 'y': Y_pred})
submission.to_csv('5_submission.csv', index=False)
# Out:
# [ 4.62701065e+03  1.94573353e-02 -1.24431970e+02 -1.24512185e+00
#   4.14690712e+01  1.36140240e+01  8.37000479e+01  5.92280952e+03
#   5.53109385e+03 -6.56212922e+02 -1.14186293e+01 -2.49511615e+04
#  -1.30039728e+01  5.07385711e-01  7.22946392e+02 -2.07844626e+04
#   2.58823897e+04 -3.11485104e+02  5.35880120e+00 -3.21235005e+03
#   8.71335483e+04 -6.40219330e+04  6.59012486e+00 -7.13151154e-02
#   3.25431229e+03 -7.02802222e+04  5.02169534e+04 -2.09484001e-02]

# %% [markdown]
# #### Calculating Mean Absoulte Error

# %%
def mean_absolute_error(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))
Y_pred_train = test(X_train)
mae_ols = mean_absolute_error(Y_train, Y_pred_train)
print(f"Mean Absolute Error (OLS): {mae_ols:.4f}")
# Out:
# [ 4.62701065e+03  1.94573353e-02 -1.24431970e+02 -1.24512185e+00
#   4.14690712e+01  1.36140240e+01  8.37000479e+01  5.92280952e+03
#   5.53109385e+03 -6.56212922e+02 -1.14186293e+01 -2.49511615e+04
#  -1.30039728e+01  5.07385711e-01  7.22946392e+02 -2.07844626e+04
#   2.58823897e+04 -3.11485104e+02  5.35880120e+00 -3.21235005e+03
#   8.71335483e+04 -6.40219330e+04  6.59012486e+00 -7.13151154e-02
#   3.25431229e+03 -7.02802222e+04  5.02169534e+04 -2.09484001e-02]
# Mean Absolute Error (OLS): 262.5906

# %%
def plot_predictions(y_true, y_pred, title):
    plt.scatter(y_true, y_pred, alpha=1, label='Predicted')
    plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], linestyle='--', color='red', label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Predicted vs. Actual Values')
    plt.legend()
    plt.show()
    
plot_predictions(Y_train, y_pred=Y_pred_train, 'Training set')

# %% [markdown]
# In OLE method to estimate the yield, on changing the features taken and on varying the polynomial degree slight changes were observed. For some features like 'Raining Days' polynomial degree of 2 led to a steep increase in MAE. So, changing and reducing features varied MAE slightly here and then but no sharp improvent can be observed after a point.

# %% [markdown]
# ### Code for Kernel Regression
# The Kernel Regression method overfits the data, gives very low MAE with the train data but doesn't perform well on Kaggle competition. Tried various combinations of features and f_taken for polynomial features.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
train_data = pd.read_csv('data/5/train.csv')
test_data = pd.read_csv('data/5/test.csv')


features = ['Row#','clonesize', 'honeybee', 'RainingDays', 'fruitset', 'fruitmass', 'seeds']
f_taken = ['seeds'] #for polynomial features


def X_creator(train_data):
    #also add constant term in each row
    d1 =  np.c_[train_data[features].values, train_data[f_taken].values**2]
    #c1 has 1 train data times
    c1 = np.ones((len(train_data),1))
    return np.hstack((c1,d1))

X_train = X_creator(train_data)
Y_train = train_data['yield'].values

X_test = X_creator(test_data)
id_test = test_data['id'].values

# print(len(X_train[0]),len(X_test[0]))
# print(len(X_test))

# Efficient kernel regression (without full matrix storage)
def test_kernel_regression(X_train, Y_train, X_test, gamma=0.1):
    n_train = X_train.shape[0]
    n_test = X_test.shape[0]
    Y_pred = np.zeros(n_test)
    
    # Iterate over test data points
    for i in range(n_test):
        x_test = X_test[i, :]
        
        # Calculate the RBF kernel (without storing the full matrix)
        K = np.exp(-gamma * np.sum((X_train - x_test) ** 2, axis=1))
        K_sum = np.sum(K)
        # Perform weighted sum of training outputs using the kernel
        Y_pred[i] = np.dot(K, Y_train) / K_sum
    
    return Y_pred

# Mean Absolute Error (MAE) from scratch
def mean_absolute_error(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

# Plot predictions for visualization
def plot_predictions(y_true, y_pred, title):
    plt.scatter(y_true, y_pred, alpha=1, label='Predicted')
    plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], linestyle='--', color='red', label='Perfect Prediction')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Predicted vs. Actual Values')
    plt.legend()
    plt.show()

Y_pred_kernel = test_kernel_regression(X_train, Y_train, X_train, gamma=0.1)

# Calculate MAE for Kernel Regression
mae_kernel = mean_absolute_error(Y_train, Y_pred_kernel)
print(f"Mean Absolute Error (Kernel Regression): {mae_kernel:.4f}")

# Final prediction for test set
Y_pred_test_kernel = test_kernel_regression(X_train, Y_train, X_test, gamma=0.1)

# Save predictions for Kernel Regression
submission_kernel = pd.DataFrame({'id': id_test, 'y': Y_pred_test_kernel})
submission_kernel.to_csv('5_Kernel_submission.csv', index=False)

# Plot Kernel Regression predictions vs actuals
plot_predictions(Y_train, Y_pred_kernel, 'Kernel Regression - Training Set')
# Out:
# Mean Absolute Error (Kernel Regression): 75.8512
